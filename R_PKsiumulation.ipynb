# %% [markdown]
# <a href="https://colab.research.google.com/github/tomonabe/PK/blob/main/R_PKsiumulation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# mrgsolveパッケージをインストール
install.packages("mrgsolve")
library(mrgsolve)
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘Rcpp’, ‘RcppArmadillo’, ‘BH’
#
#
#
# Attaching package: ‘mrgsolve’
#
#
# The following object is masked from ‘package:stats’:
#
#     filter

# %%
# 1-コンパートメントモデル経口投与
code<-" 
$PARAM
Ke = 0.15, Vd = 10, Ka = 0.8
$INIT
Xa=10, X=0
$ODE
dxdt_Xa = -Ka*Xa;
dxdt_X = Ka*Xa - Ke*X;
$CAPTURE
C = X/Vd; "

# %%
# グラフを描く
mod<-mcode("oral", code) %>% update(end = 24, delta = 0.1)
mod %>% mrgsim %>% plot
# Out:
# Building oral ...
# done.
# plot without title

# %%
# Kaを変化させてみる
idataka <- expand.idata(Ka = c(0.4, 0.8, 1.6))
out <- 
  mod %>% 
  idata_set(idataka) %>% 
  mrgsim(end=24)
plot(out, C~time)
# Out:
# plot without title

# %%
# Keを変化させてみる
idatake <- expand.idata(Ke = c(0.075, 0.15, 0.3))
out <- 
  mod %>% 
  idata_set(idatake) %>% 
  mrgsim(end=24)
plot(out, C~time)
# Out:
# plot without title

# %%
# Vdを変化させてみる
idatavd <- expand.idata(Vd = c(5, 10, 20))
out <- 
  mod %>% 
  idata_set(idatavd) %>% 
  mrgsim(end=24)
plot(out, C~time)
# Out:
# plot without title

# %%
#1-コンパートメントモデル経口投与　血中濃度を対数
code2<-" 
$PARAM
Ke = 0.15, Vd = 10, Ka = 0.8
$INIT
Xa=10, X=0
$ODE
dxdt_Xa = -Ka*Xa;
dxdt_X = Ka*Xa - Ke*X;
$CAPTURE
lnC = log(X/Vd); "

# %%
#グラフを描く
mod2<-mcode("oral2", code2) %>% update(end = 24, delta = 0.1)
mod2 %>% mrgsim %>% plot
# Out:
# Building oral2 ...
# done.
# plot without title

# %%
#Kaを変化させてみる　時間を48時間まで
idata <- expand.idata(Ka = c(0.4, 0.8, 1.6))
out <- 
  mod2 %>% 
  idata_set(idata) %>% 
  mrgsim(end=48)
plot(out, lnC~time)
# Out:
# plot without title

# %%
#Keを変化させてみる　時間を48時間まで
idatake <- expand.idata(Ke = c(0.075, 0.15, 0.3))
out <- 
  mod2 %>% 
  idata_set(idatake) %>% 
  mrgsim(end=48)
plot(out, lnC~time)
# Out:
# plot without title

# %%
#Vdを変化させてみる　時間を48時間まで
idatavd <- expand.idata(Vd= c(5, 10, 20))
out <- 
  mod2 %>% 
  idata_set(idatavd) %>% 
  mrgsim(end=48)
plot(out, lnC~time)
# Out:
# plot without title

# %%
# Keが異なる患者へ12時間ごと10 mg繰り返し投与3日間
idatake <- expand.idata(Ke = c(0.01, 0.05, 0.25))
mod %>% init(Xa=0) %>%
  ev_rx("10 q 12 x 6") %>%
  idata_set(idatake) %>% 
  mrgsim(end = 72, delta = 0.1) %>% 
  plot(C~time)
# Out:
# plot without title

# %%
# Keが異なる患者へ24時間ごと4 mg繰り返し投与30日間
idatake <- expand.idata(Ke = c(0.01, 0.05, 0.25))
mod %>% init(Xa=0) %>%
  ev_rx("4 q 24 x 30") %>%
  idata_set(idatake) %>% 
  mrgsim(end = 720, delta = 0.1) %>% 
  plot(C~time)
# Out:
# plot without title
